# %%
import numpy as np
import scipy.stats
import pylab as plt
plt.rcParams['figure.figsize'] = [8, 8]

# %% [markdown]
# Sigma = 1

# %%
def fun(x):
    return np.sqrt(2*np.pi) * x**3

# %%
xi = np.absolute(np.random.normal(0,1,100000))

# %%
integral = np.mean(fun(xi))

# %%
integral
# Out:
# np.float64(4.026919517183937)
